# %% [markdown]
# # Extracting Ontology classes and annotations(comment) from the ontology file using owlready2 library

# %%
pip install owlready2
# Out:
# Requirement already satisfied: owlready2 in c:\users\admin\anaconda-3\lib\site-packages (0.39)
# Note: you may need to restart the kernel to use updated packages.

# %%
from owlready2 import get_ontology
import pandas as pd

# %%
def read_ontology(path):

    onto = get_ontology(path)

    onto.load()



    # Read classes

    classes = []



    for cl in onto.classes():

        classes.append(cl)



    classes = list(set(classes))



    '''# Read properties

    properties = []



    for prop in onto.properties():

        properties.append(prop)



    properties = list(set(properties))'''



    return classes



def get_mappings(filename):

    mappings = []



    with open(filename) as f:

        soup = BeautifulSoup(f, 'xml')



    cells = soup.find_all('Class')



    for cell in cells:

        entity1 = cell.get_attribute_list



        mappings.append(entity1)



    return mappings




def get_path(cl):

    path = cl.name

    while True:

        try:

            path = path + '/' + cl.is_a[0].name

        except IndexError:

            break

        cl = cl.is_a[0]

        if cl == 'owl.Thing':

          #the very first node

            break



    return '/'.join(path.split('/')[::-1])




def get_classes_df(ont_path):

    data = []



    # Parse ontologies

    classes1 = read_ontology(ont_path)



    # Generate classes

    for class_ in classes1:

      data.append((class_.name.lower(),

                     get_path(class_).lower(),''.join(class_.label).lower(),''.join(class_.comment).lower()))

    dataset = pd.DataFrame(data, columns=['Name','Path','label','comment'])



    return dataset

# %%
df=get_classes_df("D:\Thesis\Ontology file\Wind energy\saref4ener.rdf")

# %%
df
# Out:
#                      Name                                         Path  \
# 0             minduration             thing/temporalentity/minduration
# 1               energymin       thing/property/energy/energy/energymin
# 2          energyskewness  thing/property/energy/energy/energyskewness
# 3           powerskewness     thing/property/power/power/powerskewness
# 4                    slot                                   thing/slot
# ..                    ...                                          ...
# 60  loadcontroleventstate      thing/state/state/loadcontroleventstate
# 61              energymax       thing/property/energy/energy/energymax
# 62       pausedurationmin        thing/temporalentity/pausedurationmin
# 63             timeperiod              thing/temporalentity/timeperiod
# 64      activedurationmax       thing/temporalentity/activedurationmax
#
#                         label  \
# 0                min duration
# 1                  energy min
# 2             energy skewness
# 3              power skewness
# 4                        slot
# ..                        ...
# 60  load control event state
# 61                 energy max
# 62         pause duration min
# 63                time period
# 64        active duration max
#
#                                               comment
# 0   if a slot has a configurable duration, it shal...
# 1   a possible type of energy in a slot that repre...
# 2   a possible type of energy in a slot that repre...
# 3   a possible type of power in a slot that repres...
# 4   the single steps of a power sequence are repre...
# ..                                                ...
# 60  in the load control, it expresses the possible...
# 61  a possible type of energy in a slot that repre...
# 62  the minimum duration a power sequence can paus...
# 63  the time period associated with load control e...
# 64  the active maximum duration a power sequence c...
#
# [65 rows x 4 columns]

# %% [markdown]
# Converting saved dataframe to a csv file

# %%
# Save the data in a CSV file

df.to_csv("ontology_data.csv", index=False)

# %%
import numpy as np
import re
import nltk
from sklearn.datasets import load_files
nltk.download('stopwords')
import pickle
from nltk.corpus import stopwords
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
ontology = pd.read_csv('D:\Thesis\Ontology file\ontology_data.csv')

# %%
ontology
# Out:
#                          Name  \
# 0           alternativesgroup
# 1              temporalentity
# 2             elapsedslottime
# 3       loadcontroleventstate
# 4               powerexpected
# ..                        ...
# 60               powerprofile
# 61          activedurationmax
# 62  activedurationdescription
# 63            defaultduration
# 64         powersequencestate
#
#                                                  Path  \
# 0                             thing/alternativesgroup
# 1                                thing/temporalentity
# 2                thing/temporalentity/elapsedslottime
# 3             thing/state/state/loadcontroleventstate
# 4            thing/property/power/power/powerexpected
# ..                                                ...
# 60                         thing/profile/powerprofile
# 61             thing/temporalentity/activedurationmax
# 62  thing/durationdescription/activedurationdescri...
# 63               thing/temporalentity/defaultduration
# 64               thing/state/state/powersequencestate
#
#                           label  \
# 0            alternatives group
# 1                           NaN
# 2             elapsed slot time
# 3     load control event state
# 4               power expected
# ..                          ...
# 60                power profile
# 61          active duration max
# 62  active duration description
# 63             default duration
# 64         power sequence state
#
#                                               comment
# 0   a collection of power sequences for a certain ...
# 1                                                 NaN
# 2   if state is set to 'running' or 'paused' and t...
# 3   in the load control, it expresses the possible...
# 4   a possible type of power in a slot that repres...
# ..                                                ...
# 60  a way to model curves of power and energy over...
# 61  the active maximum duration a power sequence c...
# 62  the duration description for the active durati...
# 63  the duration of a slot (shall be present in ca...
# 64  the current state of the power sequence. it ca...
#
# [65 rows x 4 columns]

# %%
# check missing values
ontology.isna().sum()

# drop rows with missing values
ontology = ontology.dropna()

# %%
ontology
# Out:
#                            Name  \
# 0             alternativesgroup
# 2               elapsedslottime
# 3         loadcontroleventstate
# 4                 powerexpected
# 5   slottimedurationdescription
# ..                          ...
# 60                 powerprofile
# 61            activedurationmax
# 62    activedurationdescription
# 63              defaultduration
# 64           powersequencestate
#
#                                                  Path  \
# 0                             thing/alternativesgroup
# 2                thing/temporalentity/elapsedslottime
# 3             thing/state/state/loadcontroleventstate
# 4            thing/property/power/power/powerexpected
# 5   thing/durationdescription/slottimedurationdesc...
# ..                                                ...
# 60                         thing/profile/powerprofile
# 61             thing/temporalentity/activedurationmax
# 62  thing/durationdescription/activedurationdescri...
# 63               thing/temporalentity/defaultduration
# 64               thing/state/state/powersequencestate
#
#                              label  \
# 0               alternatives group
# 2                elapsed slot time
# 3        load control event state
# 4                  power expected
# 5   slot time duration description
# ..                             ...
# 60                   power profile
# 61             active duration max
# 62     active duration description
# 63                default duration
# 64            power sequence state
#
#                                               comment
# 0   a collection of power sequences for a certain ...
# 2   if state is set to 'running' or 'paused' and t...
# 3   in the load control, it expresses the possible...
# 4   a possible type of power in a slot that repres...
# 5   the duration description for the slot time dur...
# ..                                                ...
# 60  a way to model curves of power and energy over...
# 61  the active maximum duration a power sequence c...
# 62  the duration description for the active durati...
# 63  the duration of a slot (shall be present in ca...
# 64  the current state of the power sequence. it ca...
#
# [63 rows x 4 columns]
